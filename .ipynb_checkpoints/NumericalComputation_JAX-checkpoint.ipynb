# %% [markdown]
# # Accelerated Differentiable Nonlinear-MPC for Autonomous Vehicle Drifting and Sideslip Tracking using JAX
#
# ![NLP Drift](Image/NLP_Drift.png)
#
#
# The motivation of this project is to investigate autonomous drifting control using a JAX-based automatically differentiable nonlinear Model Predictive Control (NMPC) framework for high sideslip vehicle maneuvers. The objective is to develop a control strategy that optimizes steering angle and drive torque in order to maintain stable drifting while accurately tracking a desired path and sideslip angle.
#
# To achieve this, the vehicle dynamics model and the optimization pipeline are plannned to be implemented in a fully differentiable framework using JAX, allowing gradients of the control objective to be computed automatically through automatic differentiation. It is hoped that, it may enable efficient optimization of the control inputs and improves computational performance compared with traditional NMPC implementations that rely on iteratively derived gradients or numerical approximations.
#
# Therefore, the proposed framework aims to achieve reliable autonomous drifting with accurate path tracking, while simultaneously regulating large sideslip angles to sustain controlled drift conditions and prevent vehicle spin out. The idea is that, path following mechanism is integrated into the controller to allow the vehicle to track a predefined trajectory while maintaining the high sideslip angles required for drifting.
#
# Then, performance of the proposed approach is expected to be evaluated through high-fidelity simulation scenarios, where stability, path-tracking accuracy, and computational efficiency should be analyzed. Finally, the improvements in computation speed, optimization efficiency, and control performance achieved through JAX-based acceleration are expected to be compared with traditional NMPC implementations using conventional optimization methods.
#
# ## Proposed Timeline Plan (Which shall be improvised as we learn more and more, This is only a plan and raw IDEA :D )
#
# 1. **Complete the seminars session provided and suggested by the professor.**
#
#    https://www.youtube.com/playlist?list=PLgnQpQtFTOGQo2Z_ogbonywTg8jxCI9pD
#
# 3. **USe the Seminar to build a broader understading of the research area.**
# 4. **Connect the perspectives and control and optimization.**
# 5. **Identify key challenges and solution approaches.**
# 6. **Refine the research focus of the project.**
# 7. **Study JAX libary to be used**
#
# 8. **Implement the proposed model by using JAX.**

# %%
import sys
import jax
import jax.numpy as jnp
print(jax.__version__)
# Out:
# 0.9.0.1

# %%
# !pip freeze
# Out:
# absl-py==2.4.0
# aiofiles==25.1.0
# anyio==4.12.1
# argon2-cffi==25.1.0
# argon2-cffi-bindings==25.1.0
# arrow==1.4.0
# asttokens==3.0.1
# async-lru==2.2.0
# attrs==25.4.0
# babel==2.18.0
# beautifulsoup4==4.14.3
# bleach==6.3.0
# certifi==2026.2.25
# cffi==2.0.0
# charset-normalizer==3.4.5
# chex==0.1.91
# colorama==0.4.6
# comm==0.2.3
# dataclasses-json==0.6.7
# debugpy==1.8.20
# decorator==5.2.1
# defusedxml==0.7.1
# dm-haiku==0.0.16
# etils==1.13.0
# executing==2.2.1
# fastjsonschema==2.21.2
# flax==0.12.4
# fqdn==1.5.1
# fsspec==2026.2.0
# h11==0.16.0
# httpcore==1.0.9
# httpx==0.28.1
# humanize==4.15.0
# idna==3.11
# importlib_resources==6.5.2
# ipykernel==7.2.0
# ipython==9.11.0
# ipython_pygments_lexers==1.1.1
# isoduration==20.11.0
# jax==0.9.0.1
# jaxlib==0.9.0.1
# jaxtyping==0.3.9
# jedi==0.19.2
# Jinja2==3.1.6
# jmp==0.0.4
# json5==0.13.0
# jsonpointer==3.0.0
# jsonschema==4.26.0
# jsonschema-specifications==2025.9.1
# jupyter-events==0.12.0
# jupyter-lsp==2.3.0
# ...

# %%
os.listdir("Image")
# Out:
# ['NLP_Drift.png']
